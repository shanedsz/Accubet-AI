# %% [markdown]
# # This notebook will scrape todays schedule and concatenate it to the previous dataframe

# %%
import pandas as pd
import requests
import time
import numpy as np
pd.set_option('display.max_columns', None)

# %%
test_link_url = 'https://cdn.nba.com/static/json/liveData/odds/odds_todaysGames.json'
headers  = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
test_r = requests.get(url=test_link_url, headers=headers).json()

# %%
test_r
# Out:
# {'games': [{'gameId': '0022200822',
#    'sr_id': 'sr:match:35431919',
#    'srMatchId': '35431919',
#    'homeTeamId': '1610612739',
#    'awayTeamId': '1610612765',
#    'markets': [{'name': '2way',
#      'odds_type_id': 1,
#      'group_name': 'regular',
#      'books': [{'id': 'sr:book:8072',
#        'name': 'FrancePari3',
#        'outcomes': [{'odds_field_id': 1,
#          'type': 'home',
#          'odds': '1.100',
#          'opening_odds': '1.100',
#          'odds_trend': 'down'},
#         {'odds_field_id': 2,
#          'type': 'away',
#          'odds': '6.400',
#          'opening_odds': '6.400',
#          'odds_trend': 'up'}],
#        'url': 'https://ad.doubleclick.net/ddm/trackclk/N30402.2403113NBA/B25332343.296702000;dc_trk_aid=489395076;dc_trk_cid=146209763;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=;ltd=?https://www.enligne.parionssport.fdj.fr/paris-basketball/usa/nba?filtre=58557170',
#        'countryCode': 'FR'},
# ...

# %%
matchups = test_r['games']

# %%
df = pd.DataFrame(matchups)
df
# Out:
#        gameId              sr_id srMatchId  homeTeamId  awayTeamId  \
# 0  0022200822  sr:match:35431919  35431919  1610612739  1610612765
# 1  0022200823  sr:match:35433553  35433553  1610612764  1610612766
# 2  0022200824  sr:match:35431669  35431669  1610612738  1610612755
# 3  0022200826  sr:match:35433467  35433467  1610612761  1610612759
# 4  0022200825  sr:match:35433817  35433817  1610612748  1610612754
# 5  0022200827  sr:match:35433613  35433613  1610612745  1610612758
# 6  0022200828  sr:match:35432485  35432485  1610612762  1610612750
# 7  0022200829  sr:match:35431977  35431977  1610612746  1610612742
# 8  0022200830  sr:match:35432977  35432977  1610612757  1610612744
#
#                                              markets
# 0  [{'name': '2way', 'odds_type_id': 1, 'group_na...
# 1  [{'name': '2way', 'odds_type_id': 1, 'group_na...
# 2  [{'name': '2way', 'odds_type_id': 1, 'group_na...
# 3  [{'name': '2way', 'odds_type_id': 1, 'group_na...
# ...

# %%
df.drop(columns=['sr_id','srMatchId','markets'], inplace=True)
df
# Out:
#        gameId  homeTeamId  awayTeamId
# 0  0022200822  1610612739  1610612765
# 1  0022200823  1610612764  1610612766
# 2  0022200824  1610612738  1610612755
# 3  0022200826  1610612761  1610612759
# 4  0022200825  1610612748  1610612754
# 5  0022200827  1610612745  1610612758
# 6  0022200828  1610612762  1610612750
# 7  0022200829  1610612746  1610612742
# 8  0022200830  1610612757  1610612744

# %%
df.to_csv('todays_games.csv', index=False)
