# %% [markdown]
# # This notebook will use a new machine learning library not used in class to make NBA game predictions

# %%
# Initial imports
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
import xgboost as xgb
from xgboost import XGBClassifier as xgbC
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, chi2
from imblearn.metrics import classification_report_imbalanced
from sklearn.preprocessing import MinMaxScaler

# %%
# Reading in game data
nba_df = pd.read_csv(Path('final_data.csv'),parse_dates = ['GAME_DATE'], infer_datetime_format= True)
# Changing date column to an integer
nba_df['GAME_DATE'] = nba_df['GAME_DATE'].apply(lambda x: x.toordinal())
# Resetting the index
nba_df = nba_df.reset_index()
# Dropping null values
nba_df = nba_df.dropna()
# Dropping unnecessary columns
nba_df = nba_df.drop(columns= ['index'])
# Checking dtypes
nba_df.dtypes
# Displaying dataframe
display(nba_df)
# Out:
#        HOME_TEAM_MIN  HOME_TEAM_FGM  HOME_TEAM_FGA  HOME_TEAM_FG_PCT  \
# 0             242.50          38.40          83.75           0.46050
# 1             242.50          38.15          83.60           0.45835
# 2             240.00          37.70          82.15           0.46010
# 3             240.00          38.10          82.20           0.46435
# 4             240.00          38.10          82.70           0.46140
# ...              ...            ...            ...               ...
# 24331         241.25          41.10          91.90           0.44930
# 24332         241.25          40.45          92.05           0.44080
# 24333         241.25          40.35          92.10           0.43930
# 24334         242.50          40.55          93.00           0.43720
# 24335         242.50          40.70          93.35           0.43710
#
#        HOME_TEAM_FG3M  HOME_TEAM_FG3A  HOME_TEAM_FG3_PCT  HOME_TEAM_FTM  \
# 0                6.55           16.15            0.41765          16.20
# 1                6.50           15.85            0.41825          16.50
# 2                6.25           15.25            0.41615          16.00
# 3                6.40           15.15            0.42590          16.10
# 4                6.35           15.35            0.41900          15.95
# ...               ...             ...                ...            ...
# 24331           10.30           33.30            0.30630          18.30
# 24332           10.40           33.75            0.30475          18.55
# 24333           10.35           33.20            0.31015          18.10
# 24334           10.50           33.15            0.31535          18.00
# 24335           10.50           33.30            0.31350          17.40
#
#        HOME_TEAM_FTA  HOME_TEAM_FT_PCT  ...  AWAY_TEAM_STL  AWAY_TEAM_BLK  \
# 0              21.70           0.74035  ...           7.35           4.70
# 1              21.80           0.74940  ...           7.80           5.00
# 2              21.25           0.74755  ...           7.80           5.05
# 3              21.45           0.74475  ...           8.00           5.00
# 4              21.05           0.75095  ...           7.95           5.10
# ...              ...               ...  ...            ...            ...
# 24331          24.45           0.74595  ...           7.55           5.05
# 24332          24.45           0.75685  ...           7.25           5.10
# 24333          24.05           0.74675  ...           7.40           5.50
# 24334          24.05           0.74350  ...           7.15           5.45
# 24335          23.25           0.74445  ...           7.25           4.95
#
#        AWAY_TEAM_TOV  AWAY_TEAM_PF  AWAY_TEAM_PTS  AWAY_TEAM_PLUS_MINUS  \
# 0              15.85         20.40          96.10                 -3.75
# 1              16.30         20.15          95.85                 -2.70
# 2              16.40         20.55          96.05                 -3.25
# 3              16.55         21.20          95.60                 -1.50
# 4              16.55         21.35          95.45                 -1.50
# ...              ...           ...            ...                   ...
# 24331          13.15         19.80         115.20                  1.00
# 24332          13.30         20.00         116.20                  1.00
# 24333          13.30         19.85         115.90                  2.05
# 24334          13.25         20.30         115.90                  0.85
# 24335          13.95         20.15         116.15                  1.00
#
#        HOME_TEAM_ID  GAME_DATE  AWAY_TEAM_ID  HOME_TEAM_WINS
# 0      1.610613e+09     730879  1.610613e+09             0.0
# 1      1.610613e+09     730875  1.610613e+09             0.0
# 2      1.610613e+09     730871  1.610613e+09             1.0
# 3      1.610613e+09     730869  1.610613e+09             0.0
# 4      1.610613e+09     730867  1.610613e+09             0.0
# ...             ...        ...           ...             ...
# 24331  1.610613e+09     738466  1.610613e+09             0.0
# 24332  1.610613e+09     738464  1.610613e+09             0.0
# 24333  1.610613e+09     738459  1.610613e+09             0.0
# 24334  1.610613e+09     738457  1.610613e+09             1.0
# 24335  1.610613e+09     738449  1.610613e+09             0.0
#
# [24336 rows x 44 columns]

# %%
# Separate the y variable, the labels
y = nba_df[['HOME_TEAM_WINS']]

# Separate the X variable, the features
X = nba_df.drop(columns= ['HOME_TEAM_WINS'])
display(y.head())
display(X.head())
# Out:
#    HOME_TEAM_WINS
# 0             0.0
# 1             0.0
# 2             1.0
# 3             0.0
# 4             0.0
#    HOME_TEAM_MIN  HOME_TEAM_FGM  HOME_TEAM_FGA  HOME_TEAM_FG_PCT  \
# 0          242.5          38.40          83.75           0.46050
# 1          242.5          38.15          83.60           0.45835
# 2          240.0          37.70          82.15           0.46010
# 3          240.0          38.10          82.20           0.46435
# 4          240.0          38.10          82.70           0.46140
#
#    HOME_TEAM_FG3M  HOME_TEAM_FG3A  HOME_TEAM_FG3_PCT  HOME_TEAM_FTM  \
# 0            6.55           16.15            0.41765          16.20
# 1            6.50           15.85            0.41825          16.50
# 2            6.25           15.25            0.41615          16.00
# 3            6.40           15.15            0.42590          16.10
# 4            6.35           15.35            0.41900          15.95
#
#    HOME_TEAM_FTA  HOME_TEAM_FT_PCT  ...  AWAY_TEAM_AST  AWAY_TEAM_STL  \
# 0          21.70           0.74035  ...          22.15           7.35
# 1          21.80           0.74940  ...          21.60           7.80
# 2          21.25           0.74755  ...          21.80           7.80
# 3          21.45           0.74475  ...          21.30           8.00
# 4          21.05           0.75095  ...          21.10           7.95
#
#    AWAY_TEAM_BLK  AWAY_TEAM_TOV  AWAY_TEAM_PF  AWAY_TEAM_PTS  \
# 0           4.70          15.85         20.40          96.10
# 1           5.00          16.30         20.15          95.85
# 2           5.05          16.40         20.55          96.05
# 3           5.00          16.55         21.20          95.60
# 4           5.10          16.55         21.35          95.45
#
#    AWAY_TEAM_PLUS_MINUS  HOME_TEAM_ID  GAME_DATE  AWAY_TEAM_ID
# 0                 -3.75  1.610613e+09     730879  1.610613e+09
# 1                 -2.70  1.610613e+09     730875  1.610613e+09
# 2                 -3.25  1.610613e+09     730871  1.610613e+09
# 3                 -1.50  1.610613e+09     730869  1.610613e+09
# 4                 -1.50  1.610613e+09     730867  1.610613e+09
#
# [5 rows x 43 columns]

# %%
# Scaling the data using MinMax scaler
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Define search space for grid search
search_space = [
  {
    'clf__n_estimators': [50, 100, 150, 200],
    'clf__learning_rate': [0.01, 0.1, 0.2, 0.3],
    'clf__max_depth': range(3, 10),
  }
]

# %%
# Define cross validation
kfold = KFold(n_splits=10, random_state=42, shuffle=True)

# %%
# AUC and accuracy as score
scoring = {'AUC':'roc_auc', 'Accuracy':make_scorer(accuracy_score)}

# %%
# Define grid search
grid = RandomizedSearchCV(
  estimator=clf_xgb,
  param_distributions=search_space,
  cv=kfold,
  scoring=scoring,
  refit='AUC',
  verbose=1,
  n_jobs=-1
)
# Fit grid search
model = grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [17:08:29] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:29] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:29] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:29] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:58] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:58] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:23] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:23] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:23] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:24] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:45] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:46] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:46] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:47] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:09] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:09] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:10] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:10] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:30] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:30] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:31] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:32] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:04] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:05] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:06] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:06] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:31] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:32] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:32] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:32] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:54] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:54] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:54] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:11:55] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:12:19] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:12:19] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:12:19] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:12:20] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:12:39] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:12:39] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:12:39] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:12:40] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:05] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:06] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:06] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:07] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:33] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:33] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:34] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:34] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:56] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:57] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:57] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:57] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:17] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:17] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:18] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:18] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:37] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
# [17:14:37] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
#
# [17:14:38] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:39] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:14:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:00] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:22] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:22] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:22] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:22] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:40] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:40] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:40] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:40] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:15:59] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:19] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:19] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:19] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:20] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:40] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:41] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:41] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:41] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:04] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:04] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:04] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:04] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:29] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:30] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:30] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:30] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:51] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:51] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:52] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:17:52] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:18:13] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
predict = model.predict(X_test)
print('Best AUC Score: {}'.format(model.best_score_))
print('Accuracy: {}'.format(accuracy_score(y_test, predict)))
print(confusion_matrix(y_test,predict))
# Out:
# Best AUC Score: 0.6380513665838744
# Accuracy: 0.6071663379355687
# [[ 306 2179]
#  [ 211 3388]]

# %%
print(model.best_params_)
# Out:
# {'clf__n_estimators': 200, 'clf__max_depth': 7, 'clf__learning_rate': 0.1}

# %%
clf_xgb = xgb.XGBClassifier(objective='binary:logistic', 
                            eval_metric="aucpr",
                            seed=42, 
                            scale_pos_weight=5,
                            use_label_encoder=False,
                            clf__learning_rate=0.1,
                            clf__max_depth = 7,
                            clf__n_estimators = 200)

# %%
clf_xgb.fit(X_train, 
            y_train,
            verbose=True, ## the next three arguments set up early stopping.
            early_stopping_rounds=10,
            eval_set=[(X_test, y_test)])
# Out:
# [17:24:33] WARNING: ../src/learner.cc:576:
# Parameters: { "clf__learning_rate", "clf__max_depth", "clf__n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-aucpr:0.73948
# [1]	validation_0-aucpr:0.73985
# [2]	validation_0-aucpr:0.74294
# [3]	validation_0-aucpr:0.74206
# [4]	validation_0-aucpr:0.74080
# [5]	validation_0-aucpr:0.74001
# [6]	validation_0-aucpr:0.74073
# [7]	validation_0-aucpr:0.73781
# [8]	validation_0-aucpr:0.73797
# [9]	validation_0-aucpr:0.73795
# [10]	validation_0-aucpr:0.73682
# [11]	validation_0-aucpr:0.73584
# [12]	validation_0-aucpr:0.73346
# XGBClassifier(base_score=0.5, booster='gbtree', clf__learning_rate=0.1,
#               clf__max_depth=7, clf__n_estimators=200, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='aucpr', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=5, seed=42,
#               subsample=1, ...)

# %%
# Setting XGB classifier instance
#xgb_clf = xgb.XGBClassifier()
# Fitting the data to the model
#xgb_clf = xgb_clf.fit(X_train, y_train)
# Making predictions
predictions = clf_xgb.predict(X_test)

# %%
# Checking accuracy score
accuracy_score(y_test, predictions)
# Out:
# 0.6000986193293886

# %%
# Viewing classification report
print(classification_report_imbalanced(y_test, predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#         0.0       0.76      0.03      0.99      0.06      0.17      0.03      2485
#         1.0       0.60      0.99      0.03      0.75      0.17      0.03      3599
#
# avg / total       0.66      0.60      0.42      0.47      0.17      0.03      6084
